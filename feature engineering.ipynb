# %%
import pandas as pd
import os

# %%
cwd = os.getcwd()
data_folder = os.path.join(cwd, "sales_forecasting_data")

df = pd.read_csv(os.path.join(data_folder, "clean_train.csv"))

# %%
df
# Out:
#                  id        date  store_nbr  item_nbr  unit_sales  onpromotion  \
# 0               200  2013-01-01         25    463598         3.0        False
# 1               517  2013-01-01         25   1047686         1.0        False
# 2               460  2013-01-01         25    936994         2.0        False
# 3               277  2013-01-01         25    586969         1.0        False
# 4               317  2013-01-01         25    683722         1.0        False
# ...             ...         ...        ...       ...         ...          ...
# 25593623  125453739  2017-08-15         34   1004551         1.0        False
# 25593624  125450647  2017-08-15         32    557257         2.0        False
# 25593625  125465865  2017-08-15         41    510054         4.0        False
# 25593626  125453890  2017-08-15         34   1147731         5.0        False
# 25593627  125478674  2017-08-15         46   1920071         5.0        False
#
#                     family  class  perishable       city        state type_x  \
# 0                 CLEANING   3024           0    Salinas  Santa Elena      D
# 1                BEVERAGES   1120           0    Salinas  Santa Elena      D
# 2                GROCERY I   1004           0    Salinas  Santa Elena      D
# 3                GROCERY I   1004           0    Salinas  Santa Elena      D
# 4                GROCERY I   1062           0    Salinas  Santa Elena      D
# ...                    ...    ...         ...        ...          ...    ...
# 25593623  LIQUOR,WINE,BEER   1318           0  Guayaquil       Guayas      B
# 25593624              EGGS   2502           1  Guayaquil       Guayas      C
# 25593625         GROCERY I   1072           0    Machala       El Oro      D
# 25593626        AUTOMOTIVE   6806           0  Guayaquil       Guayas      B
# 25593627         GROCERY I   1016           0      Quito    Pichincha      A
#
#           cluster  transactions  dcoilwtico  holiday
# 0               1         770.0       93.14     True
# 1               1         770.0       93.14     True
# 2               1         770.0       93.14     True
# 3               1         770.0       93.14     True
# 4               1         770.0       93.14     True
# ...           ...           ...         ...      ...
# 25593623        6        2007.0       47.57     True
# 25593624        3         615.0       47.57     True
# 25593625        4        1003.0       47.57     True
# 25593626        6        2007.0       47.57     True
# 25593627       14        3197.0       47.57     True
#
# [25593628 rows x 16 columns]

# %%
# Add dow and month
df['date'] = pd.to_datetime(df['date'])

df['dow'] = df['date'].dt.dayofweek
df['month'] = df['date'].dt.month

# %%
df = df.drop('date', axis=1)
df = df.drop('holiday', axis=1)

# %%
df
# Out:
#                  id  store_nbr  item_nbr  unit_sales  onpromotion  \
# 0               200         25    463598         3.0        False
# 1               517         25   1047686         1.0        False
# 2               460         25    936994         2.0        False
# 3               277         25    586969         1.0        False
# 4               317         25    683722         1.0        False
# ...             ...        ...       ...         ...          ...
# 25593623  125453739         34   1004551         1.0        False
# 25593624  125450647         32    557257         2.0        False
# 25593625  125465865         41    510054         4.0        False
# 25593626  125453890         34   1147731         5.0        False
# 25593627  125478674         46   1920071         5.0        False
#
#                     family  class  perishable       city        state type_x  \
# 0                 CLEANING   3024           0    Salinas  Santa Elena      D
# 1                BEVERAGES   1120           0    Salinas  Santa Elena      D
# 2                GROCERY I   1004           0    Salinas  Santa Elena      D
# 3                GROCERY I   1004           0    Salinas  Santa Elena      D
# 4                GROCERY I   1062           0    Salinas  Santa Elena      D
# ...                    ...    ...         ...        ...          ...    ...
# 25593623  LIQUOR,WINE,BEER   1318           0  Guayaquil       Guayas      B
# 25593624              EGGS   2502           1  Guayaquil       Guayas      C
# 25593625         GROCERY I   1072           0    Machala       El Oro      D
# 25593626        AUTOMOTIVE   6806           0  Guayaquil       Guayas      B
# 25593627         GROCERY I   1016           0      Quito    Pichincha      A
#
#           cluster  transactions  dcoilwtico  dow  month
# 0               1         770.0       93.14    1      1
# 1               1         770.0       93.14    1      1
# 2               1         770.0       93.14    1      1
# 3               1         770.0       93.14    1      1
# 4               1         770.0       93.14    1      1
# ...           ...           ...         ...  ...    ...
# 25593623        6        2007.0       47.57    1      8
# 25593624        3         615.0       47.57    1      8
# 25593625        4        1003.0       47.57    1      8
# 25593626        6        2007.0       47.57    1      8
# 25593627       14        3197.0       47.57    1      8
#
# [25593628 rows x 16 columns]
